# %% [markdown]
# # Dataset-02 US Mortality Dataset
# ## Name-Sadhvi Dubey
# ## Student ID- x19199350
# ## MSCDA-Group A
# ## Group number-25

# %% [markdown]
# #### Getting US CDC Mortality Dataset into CSV format

# %%
# The data was available in a format prescribed by the CDC, it is processed using a python script to convert the file into a csv format.
# URL -https://www.cdc.gov/nchs/data_access/vitalstatsonline.htm
# CDC 2019 PDF - https://www.cdc.gov/nchs/data/dvs/Multiple-Cause-Record-Layout-2019-508.pdf

# 1. Have Python installed.
# 2. Get & unzip mortality file
# 3. Tweak fileObj and FileOutObj to point to the source and destination of your choosing.



fileObj = open("C:\data\PO1\VS13MORT.DUSMCPUB",'r')
fileOutObj = open("C:\data\PO1\VS13MORT.csv","a")

fileOutObj.write('Resident_Status, Education, Month_Of_Death, Sex, Age_Key, Age_Value, Age_Sub_Flag, Age_Recode_52, Age_Recode_27, ' + \
                 'Age_Recode_12, Infant_Age_Recode_22, Place_Of_Death, Marital_Status, DOW_of_Death, Data_Year, Injured_At_Work, ' + \
                 'Manner_Of_Death, Method_Of_Disposition, Autopsy, Activity_Code, Place_Of_Causal_Injury,  ICD10, Cause_Recode_358, ' + \
                 'Cause_Recode_113, Infant_Cause_Recode_130, Cause_Recode_39, Entity_Axis_Conditions, EAC1, EAC2, EAC3, EAC4, EAC5, ' + \
                 'EAC6, EAC7, EAC8, EAC9, EAC10, EAC11, EAC12, EAC13, EAC14, EAC15, EAC16, EAC17, EAC18, EAC19, EAC20, ' + \
                 'Record_Axis_Conditions, RA1, RA2, RA3, RA4, RA5, RA6, RA7, RA8, RA9, RA10, RA11, RA12, RA13, RA14, ' + \
                 'RA15, RA16, RA17, RA18, RA19, RA20, Race, Race_Bridged, Race_Imputation, Race_Recode_3, Race_Recode_5, ' + \
                 'Hispanic_Origin, Hispanic_Origin_Recode\n')

outStr = ""

for line in fileObj:

               Resident_Status = line[19].strip()
               Education = line[60:62].strip()
               Month_Of_Death = line[63:67].strip()
               Sex = line[68].strip()
               Age_Key = line[69].strip()
               Age_Value = line[70:73].strip()
               Age_Sub_Flag = line[73].strip()
               Age_Recode_52 = line[74:76].strip()
               Age_Recode_27 = line[76:78].strip()
               Age_Recode_12 = line[78:80].strip()
               Infant_Age_Recode_22 = line[80:82].strip()
               Place_Of_Death = line[82].strip()
               Marital_Status = line[83].strip()
               DOW_of_Death = line[84].strip()
               Data_Year = line[101:105].strip()
               Injured_At_Work = line[105].strip()
               Manner_Of_Death = line[106].strip()
               Method_Of_Disposition = line[107].strip()
               Autopsy = line[108].strip()
               Activity_Code = line[143].strip()
               Place_Of_Causal_Injury = line[144].strip()
               ICD10 = line[145:149].strip()
               Cause_Recode_358 = line[149:152].strip()
               Cause_Recode_113 = line[153:156].strip()
               Infant_Cause_Recode_130 = line[156:159].strip()
               Cause_Recode_39 = line[159:161].strip()
               Entity_Axis_Conditions = line[162:164].strip()
               EAC1 = line[164:171].strip()
               EAC2 = line[171:178].strip()
               EAC3 = line[178:185].strip()
               EAC4 = line[185:192].strip()
               EAC5 = line[192:199].strip()
               EAC6 = line[199:206].strip()
               EAC7 = line[206:213].strip()
               EAC8 = line[213:220].strip()
               EAC9 = line[220:227].strip()
               EAC10 = line[227:234].strip()
               EAC11 = line[234:241].strip()
               EAC12 = line[241:248].strip()
               EAC13 = line[248:255].strip()
               EAC14 = line[255:262].strip()
               EAC15 = line[262:269].strip()
               EAC16 = line[269:276].strip()
               EAC17 = line[276:283].strip()
               EAC18 = line[283:290].strip()
               EAC19 = line[290:297].strip()
               EAC20 = line[297:304].strip()
               Record_Axis_Conditions = line[340:342]
               RA1 = line[343:348].strip()
               RA2 = line[348:353].strip()
               RA3 = line[353:358].strip()
               RA4 = line[358:363].strip()
               RA5 = line[363:368].strip()
               RA6 = line[368:373].strip()
               RA7 = line[373:378].strip()
               RA8 = line[378:383].strip()
               RA9 = line[383:388].strip()
               RA10 = line[388:393].strip()
               RA11 = line[393:398].strip()
               RA12 = line[398:403].strip()
               RA13 = line[403:408].strip()
               RA14 = line[408:413].strip()
               RA15 = line[413:418].strip()
               RA16 = line[418:423].strip()
               RA17 = line[423:428].strip()
               RA18 = line[428:433].strip()
               RA19 = line[433:438].strip()
               RA20 = line[438:443].strip()
               Race = line[444:446].strip()
               Race_Bridged = line[446].strip()
               Race_Imputation = line[447].strip()
               Race_Recode_3 = line[448].strip()
               Race_Recode_5 = line[449].strip()
               Hispanic_Origin = line[483:486].strip()
               Hispanic_Origin_Recode = line[487].strip()
               
               
               
               
               
               outStr = (Resident_Status +              ', ' + Education +              ', ' + Month_Of_Death +         ', ' + Sex + \
                         ', ' + Age_Key +               ', ' + Age_Value +              ', ' + Age_Sub_Flag +           ', ' + Age_Recode_52 + \
                         ', ' + Age_Recode_27 +         ', ' + Age_Recode_12 +          ', ' + Infant_Age_Recode_22 +   ', ' + Place_Of_Death + \
                         ', ' + Marital_Status +        ', ' + DOW_of_Death +           ', ' + Data_Year +              ', ' + Injured_At_Work +  \
                         ', ' + Manner_Of_Death +       ', ' + Method_Of_Disposition +  ', ' + Autopsy +                ', ' + Activity_Code + \
                         ', ' + Place_Of_Causal_Injury +', ' + ICD10 +                  ', ' + Cause_Recode_358 +       ', ' + Cause_Recode_113 +  \
                         ', ' + Infant_Cause_Recode_130 + ', ' + Cause_Recode_39 +      ', ' + Entity_Axis_Conditions + ', ' + EAC1 + \
                         ', ' + EAC2 +                  ', ' + EAC3 +                   ', ' + EAC4 +                   ', ' + EAC5 + \
                         ', ' + EAC6 +                  ', ' + EAC7 +                   ', ' + EAC8 +                   ', ' + EAC9 + \
                         ', ' + EAC10 +                 ', ' + EAC11 +                  ', ' + EAC12 +                  ', ' + EAC13 + \
                         ', ' + EAC14 +                 ', ' + EAC15 +                  ', ' + EAC16 +                  ', ' + EAC17 + \
                         ', ' + EAC18 +                 ', ' + EAC19 +                  ', ' + EAC20 +                  ', ' + Record_Axis_Conditions + \
                         ', ' + RA1 +                   ', ' + RA2 +                    ', ' + RA3 +                    ', ' + RA4 + \
                         ', ' + RA5 +                   ', ' + RA6 +                    ', ' + RA7 +                    ', ' + RA8 + \
                         ', ' + RA9 +                   ', ' + RA10 +                   ', ' + RA11 +                   ', ' + RA12 + \
                         ', ' + RA13 +                  ', ' + RA14 +                   ', ' + RA15 +                   ', ' + RA16 + \
                         ', ' + RA17 +                  ', ' + RA18 +                   ', ' + RA19 +                   ', ' + RA20 + \
                         ', ' + Race +                  ', ' + Race_Bridged +           ', ' + Race_Imputation +        ', ' + Race_Recode_3 + \
                         ', ' + Race_Recode_5 +         ', ' + Hispanic_Origin +        ', ' + Hispanic_Origin_Recode + '\n')


               
               fileOutObj.write(outStr)



print("Parse complete.")
fileOutObj.close()
fileObj.close()

# %%
import json
import pymongo
from pymongo import MongoClient

import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from sqlalchemy import create_engine
import psycopg2 
import io

# %% [markdown]
# # Connecting to Mongodb

# %%
cluster = pymongo.MongoClient("mongodb+srv://x19199350:AH5wxFXcgbMSAuKS@clusterdap.ozzj2.mongodb.net/Dataset02?retryWrites=true&w=majority")

# %%
db = cluster["Dataset02"]

# %%
collection = db["us_mort_raw"]

# %% [markdown]
# ## Export data CSV to Mongo DB

# %%
#export data CSV to Mongo DB

ds= pd.read_csv("us_cdc_sorted.csv")
data = ds.to_dict('records')
collection.insert_many(data, ordered=False)
print("All the Data has been Exported to Mongo DB Server .... ")
# Out:
# All the Data has been Exported to Mongo DB Server ....

# %% [markdown]
# # Dataset pre-processing

# %%
#Dataset pre-processing
#1
vals = {
    ' S':'single',
    ' D':'divorced',
    ' W':'widowed',
    ' U':'unknown',
    ' M':'married'
        }
for key,value in vals.items():
    print(key,value)
    myquery = { 'Marital_Status': key } # select query with old columns value
    newvalues = { "$set": { 'marital': value } } #creates new column with new value
    results = collection.update_many(myquery, newvalues)
# Out:
#  S single
#  D divorced
#  W widowed
#  U unknown
#  M married

# %%
#2

vals = {
        101:'Jan',
        102:'Feb',
        103:'Mar',
        104:'Apr',
        105:'May',
        106:'Jun',
        107:'Jul',
        108:'Aug',
        109:'Sep',
        110:'Oct',
        111:'Nov',
        112:'Dec'
        }

for key,value in vals.items():
    print(key,value)
    myquery = { ' Month_Of_Death': key } # select query with old columns value
    newvalues = { "$set": { 'month': value } } #creates new column with new value
    results = collection.update_many(myquery, newvalues)
# Out:
# 101 Jan
# 102 Feb
# 103 Mar
# 104 Apr
# 105 May
# 106 Jun
# 107 Jul
# 108 Aug
# 109 Sep
# 110 Oct
# 111 Nov
# 112 Dec

# %%
#3

vals = {
        1:'accident',
        2:'suicide',
        3:'homicide',
        4:'unknown',
        5:'law/war',
        7:'natural',
        'NaN' :'not_specified'
         }

for key,value in vals.items():
    print(key,value)
    myquery = { 'Manner_Of_Death': key } # select query with old columns value
    newvalues = { "$set": { 'type_death': value } } #creates new column with new value
    results = collection.update_many(myquery, newvalues)
# Out:
# 1 accident
# 2 suicide
# 3 homicide
# 4 unknown
# 5 law/war
# 7 natural
# NaN not_specified

# %%
#4
vals ={
       1:'public hospital',
       2:'public hospital',
       3:'public hospital',
       4:'home',
       5:'public hospital',
       6:'private hospital',
       7:'other',
       9:'unknown'
        }

for key,value in vals.items():
    print(key,value)
    myquery = { 'Place_Of_Death': key } # select query with old columns value
    newvalues = { "$set": { 'place_death': value } } #creates new column with new value
    results = collection.update_many(myquery, newvalues)
# Out:
# 1 public hospital
# 2 public hospital
# 3 public hospital
# 4 home
# 5 public hospital
# 6 private hospital
# 7 other
# 9 unknown

# %%
#5

vals= {
       1:'sunday',
       2:'monday',
       3:'tuesday',
       4:'wednesday',
       5:'thursday',
       6:'friday',
       7:'saturday',
       9:'unknown'
        }

for key,value in vals.items():
    print(key,value)
    myquery = { 'DOW_of_Death': key } # select query with old columns value
    newvalues = { "$set": { 'day_of_death': value } } #creates new column with new value
    results = collection.update_many(myquery, newvalues)
# Out:
# 1 sunday
# 2 monday
# 3 tuesday
# 4 wednesday
# 5 thursday
# 6 friday
# 7 saturday
# 9 unknown

# %%
#6

vals = {
        ' M':'male',
        ' F':'female'
         }

for key,value in vals.items():
    print(key,value)
    myquery = { ' Sex': key } # select query with old columns value
    newvalues = { "$set": { 'sex' : value } } #creates new column with new value
    results = collection.update_many(myquery, newvalues)
# Out:
#  M male
#  F female

# %%
#7

vals = {
        1:'US_residents',
        2:'intrastate_nonresidents',
        3:'interterritory_nonresidents',
        4:'foreign_residents'
         }

for key,value in vals.items():
    print(key,value)
    myquery = { 'Resident_Status': key } # select query with old columns value
    newvalues = { "$set": { 'resident_status' : value } } #creates new column with new value
    results = collection.update_many(myquery, newvalues)
# Out:
# 1 US_residents
# 2 intrastate_nonresidents
# 3 interterritory_nonresidents
# 4 foreign_residents

# %%
#8
vals ={
       'B':'Burial',
       'C':'Cremation',
       'D':'Other',
       'U':'Unknown'
         }
for key,value in vals.items():
    print(key,value)
    myquery = { 'Method_Of_Disposition': key } # select query with old columns value
    newvalues = { "$set": { 'method_of_disposition' : value } } #creates new column with new value
    results = collection.update_many(myquery, newvalues)
# Out:
# B Burial
# C Cremation
# D Other
# U Unknown

# %%
#9
vals = {
        1:'White',
        2:'Black',
        3:'American_Indian ',
        4:'Chinese',
        5:'Japanese',
        6:'Hawaiian',
        7:'Filipino',
        18:'Asian_Indian',
        28:'Korean',
        38:'Samoan',
        48:'Vietnamese',
        58:'Guamanian',
        68:'Other',
        78:'Pacific_Islander'
          }

for key,value in vals.items():
    print(key,value)
    myquery = { 'Race': key } # select query with old columns value
    newvalues = { "$set": {'race': value } } #creates new column with new value
    results = collection.update_many(myquery, newvalues)
# Out:
# 1 White
# 2 Black
# 3 American_Indian
# 4 Chinese
# 5 Japanese
# 6 Hawaiian
# 7 Filipino
# 18 Asian_Indian
# 28 Korean
# 38 Samoan
# 48 Vietnamese
# 58 Guamanian
# 68 Other
# 78 Pacific_Islander

# %%
#10
vals = {
        1:'Under 1 year',
        2 :'1-4 years',
        3 :'5-14 years',
        4 :'15-24 years',
        5: '25-34 years',
        6: '35-44 years',
        7: '45-54 years',
        8: '55-64 years',
        9: '65-74 years',
       10: '75-84 years',
       11: '85 years and over',
       12: 'Age not stated'
       }

for key,value in vals.items():
    print(key,value)
    myquery = { 'Age_Recode_12': key } # select query with old columns value
    newvalues = { "$set": { 'age_group': value } } #creates new column with new value
    results = collection.update_many(myquery, newvalues)
# Out:
# 1 Under 1 year
# 2 1-4 years
# 3 5-14 years
# 4 15-24 years
# 5 25-34 years
# 6 35-44 years
# 7 45-54 years
# 8 55-64 years
# 9 65-74 years
# 10 75-84 years
# 11 85 years and over
# 12 Age not stated

# %%
records = collection.find({})
ds=pd.DataFrame(list(records))

# %%
ds
# Out:
#                            _id  Resident_Status   Month_Of_Death  Sex  \
# 0     60868909c954f164e06e7ca3                1              102    M
# 1     60868909c954f164e06e7ca4                1              112    M
# 2     60868909c954f164e06e7ca5                1              105    F
# 3     60868909c954f164e06e7ca6                2              110    F
# 4     60868909c954f164e06e7ca7                1              105    F
# ...                        ...              ...              ...  ...
# 6234  60868909c954f164e06e94fd                1              106    F
# 6235  60868909c954f164e06e94fe                1              111    M
# 6236  60868909c954f164e06e94ff                1              111    M
# 6237  60868909c954f164e06e9500                1              102    F
# 6238  60868909c954f164e06e9501                1              112    F
#
#        Age_Key   Age_Value   Age_Recode_52  Age_Recode_27  Age_Recode_12  \
# ...

# %% [markdown]
# # Droping columns from Dataset02

# %%
#droping columns from Dataset02

ds=ds.drop(columns=['_id','Age_Recode_27','Resident_Status',' Month_Of_Death',' Sex',' Age_Key',' Age_Value',' Age_Recode_52','Age_Recode_12','Place_Of_Death','Marital_Status','DOW_of_Death','Manner_Of_Death','Method_Of_Disposition','Cause_Recode_358','Cause_Recode_113','Cause_Recode_39','Race'], axis=1)

# %%
ds
# Out:
#       ICD10   marital month       place_death day_of_death  \
# 0      C349   married   Feb              home       friday
# 1      J100  divorced   Dec   public hospital     thursday
# 2       F03   widowed   May              home     thursday
# 3       N19   widowed   Oct  private hospital    wednesday
# 4      K760    single   May   public hospital     thursday
# ...     ...       ...   ...               ...          ...
# 6234   J449   widowed   Jun              home      tuesday
# 6235    X95    single   Nov              home       sunday
# 6236   A419   married   Nov  private hospital     saturday
# 6237   I959   unknown   Feb   public hospital      tuesday
# 6238   C259   widowed   Dec              home      tuesday
#
#               resident_status        race          age_group     sex  \
# 0                US_residents       White        65-74 years    male
# 1                US_residents       Black        65-74 years    male
# ...

# %%
results.modified_count
# Out:
# 0

# %%
ds=ds.rename(columns={'ICD10':'icd10_code'})

# %%
ds['icd10_code'] = ds['icd10_code'].str.strip()

# %%
ds
# Out:
#      icd10_code   marital month       place_death day_of_death  \
# 0          C349   married   Feb              home       friday
# 1          J100  divorced   Dec   public hospital     thursday
# 2           F03   widowed   May              home     thursday
# 3           N19   widowed   Oct  private hospital    wednesday
# 4          K760    single   May   public hospital     thursday
# ...         ...       ...   ...               ...          ...
# 6234       J449   widowed   Jun              home      tuesday
# 6235        X95    single   Nov              home       sunday
# 6236       A419   married   Nov  private hospital     saturday
# 6237       I959   unknown   Feb   public hospital      tuesday
# 6238       C259   widowed   Dec              home      tuesday
#
#               resident_status        race          age_group     sex  \
# 0                US_residents       White        65-74 years    male
# ...

# %%
ds['icd10_code'] = ds.icd10_code.astype(str)

# %%
ds
# Out:
#      icd10_code   marital month       place_death day_of_death  \
# 0          C349   married   Feb              home       friday
# 1          J100  divorced   Dec   public hospital     thursday
# 2           F03   widowed   May              home     thursday
# 3           N19   widowed   Oct  private hospital    wednesday
# 4          K760    single   May   public hospital     thursday
# ...         ...       ...   ...               ...          ...
# 6234       J449   widowed   Jun              home      tuesday
# 6235        X95    single   Nov              home       sunday
# 6236       A419   married   Nov  private hospital     saturday
# 6237       I959   unknown   Feb   public hospital      tuesday
# 6238       C259   widowed   Dec              home      tuesday
#
#               resident_status        race          age_group     sex  \
# 0                US_residents       White        65-74 years    male
# ...

# %%
ds.dtypes
# Out:
# icd10_code         object
# marital            object
# month              object
# place_death        object
# day_of_death       object
# resident_status    object
# race               object
# age_group          object
# sex                object
# type_death         object
# dtype: object

# %%
ds.describe()
# Out:
#        icd10_code  marital month      place_death day_of_death  \
# count        6239     6239  6239             6239         6239
# unique        635        5    12                5            7
# top          I251  married   Dec  public hospital     thursday
# freq          337     2316   567             2710          950
#
#        resident_status   race          age_group   sex type_death
# count             6239   6239               6239  6239       4643
# unique               4     14                 11     2          6
# top       US_residents  White  85 years and over  male    natural
# freq              5246   5163               1904  3273       4061

# %%
#COUNT OF columns and rows
ds.shape
# Out:
# (6239, 9)

# %%
ds
# Out:
#      icd10_code   marital month       place_death day_of_death  \
# 0          C349   married   Feb              home       friday
# 1          J100  divorced   Dec   public hospital     thursday
# 2           F03   widowed   May              home     thursday
# 3           N19   widowed   Oct  private hospital    wednesday
# 4          K760    single   May   public hospital     thursday
# ...         ...       ...   ...               ...          ...
# 6234       J449   widowed   Jun              home      tuesday
# 6235        X95    single   Nov              home       sunday
# 6236       A419   married   Nov  private hospital     saturday
# 6237       I959   unknown   Feb   public hospital      tuesday
# 6238       C259   widowed   Dec              home      tuesday
#
#               resident_status        race          age_group     sex  \
# 0                US_residents       White        65-74 years    male
# ...

# %% [markdown]
# # Connecting to SQL

# %%
import sqlalchemy
import psycopg2
import pymysql
import psycopg2.extras as extras
conn = psycopg2.connect(
host="ncirl-az01.westeurope.cloudapp.azure.com",
database="remotedap",
user="remotedap2",
password="Hola1234",
port=5432)

from sqlalchemy import create_engine
engine = create_engine('postgresql://remotedap2:Hola1234@ncirl-az01.westeurope.cloudapp.azure.com:5432/remotedap')

# %% [markdown]
# # Creating table in postgresql

# %%
#creating table in postgresql
ds.to_sql('us_mort',engine)

# %%
ds
# Out:
#      icd10_code   marital month       place_death day_of_death  \
# 0          C349   married   Feb              home       friday
# 1          J100  divorced   Dec   public hospital     thursday
# 2           F03   widowed   May              home     thursday
# 3           N19   widowed   Oct  private hospital    wednesday
# 4          K760    single   May   public hospital     thursday
# ...         ...       ...   ...               ...          ...
# 6234       J449   widowed   Jun              home      tuesday
# 6235        X95    single   Nov              home       sunday
# 6236       A419   married   Nov  private hospital     saturday
# 6237       I959   unknown   Feb   public hospital      tuesday
# 6238       C259   widowed   Dec              home      tuesday
#
#               resident_status        race          age_group     sex  \
# 0                US_residents       White        65-74 years    male
# ...

# %%
cursor = conn.cursor()
cursor.execute("ALTER TABLE us_mort ADD COLUMN icd10_chapter varchar(25);")
conn.commit()
cursor.close()

# %%
ALTER TABLE us_mort ADD COLUMN icd10_block numeric;

# %%
cursor = conn.cursor()
cursor.execute("update us_mort set icd10_chapter='A00–B99' where icd10_code LIKE '%A%';")
cursor.execute("update us_mort set icd10_chapter='C00–D48' where icd10_code LIKE '%B%';")
cursor.execute("update us_mort set icd10_chapter='D50–D89' where icd10_code LIKE '%C%';")
cursor.execute("update us_mort set icd10_chapter='E00–E90' where icd10_code LIKE '%D%';")
cursor.execute("update us_mort set icd10_chapter='F00–F99' where icd10_code LIKE '%E%';")
cursor.execute("update us_mort set icd10_chapter='G00–G99' where icd10_code LIKE '%F%';")
cursor.execute("update us_mort set icd10_chapter='H00–H59' where icd10_code LIKE '%G%';")
cursor.execute("update us_mort set icd10_chapter='H60–H95' where icd10_code LIKE '%H%';")
cursor.execute("update us_mort set icd10_chapter='I00–I99' where icd10_code LIKE '%I%';")
cursor.execute("update us_mort set icd10_chapter='J00–J99' where icd10_code LIKE '%J%';")
cursor.execute("update us_mort set icd10_chapter='K00–K93' where icd10_code LIKE '%K%';")
cursor.execute("update us_mort set icd10_chapter='L00–L99' where icd10_code LIKE '%L%';")
cursor.execute("update us_mort set icd10_chapter='M00–M99' where icd10_code LIKE '%M%';")
cursor.execute("update us_mort set icd10_chapter='N00–N99' where icd10_code LIKE '%N%';")
cursor.execute("update us_mort set icd10_chapter='O00–O99' where icd10_code LIKE '%O%';")
cursor.execute("update us_mort set icd10_chapter='P00–P96' where icd10_code LIKE '%P%';")
cursor.execute("update us_mort set icd10_chapter='Q00–Q99' where icd10_code LIKE '%Q%';")
cursor.execute("update us_mort set icd10_chapter='R00–R99' where icd10_code LIKE '%R%';")
cursor.execute("update us_mort set icd10_chapter='S00–T98' where icd10_code LIKE '%S%';")
cursor.execute("update us_mort set icd10_chapter='V01–Y98' where icd10_code LIKE '%V%';")
cursor.execute("update us_mort set icd10_chapter='Z00–Z99' where icd10_code LIKE '%Z%';")
cursor.execute("update us_mort set icd10_chapter='U00–U99' where icd10_code LIKE '%U%';")
conn.commit()
cursor.close()

# %%
#reading data from postgresql
ds_sql= pd.read_sql_query('select * from "us_mort"',engine)

# %%
ds_sql
# Out:
#       index icd10_code   marital month       place_death day_of_death  \
# 0         4       K760    single   May   public hospital     thursday
# 1        32       K703   married   Oct   public hospital       monday
# 2        39       K922  divorced   Mar   public hospital     thursday
# 3        43       K746   married   Apr   public hospital      tuesday
# 4        52       K729   married   Aug   public hospital     saturday
# ...     ...        ...       ...   ...               ...          ...
# 5776   5715       G309   married   Oct  private hospital       monday
# 5777   5719       G122   married   Nov              home    wednesday
# 5778   5728        G20    single   Oct              home    wednesday
# 5779   6229       G309   widowed   Oct              home       friday
# 5780   6233       G309   married   Dec  private hospital    wednesday
#
#               resident_status              race          age_group     sex  \
# ...

# %%
ds_sql['icd10_chapter'] = ds_sql.icd10_chapter.astype(str)

# %%
ds_sql['age_group'] = ds_sql.age_group.astype(str)

# %%
ds_sql['type_death'] = ds_sql.type_death.astype(str)

# %%
selData = ds_sql[['icd10_chapter', 'age_group', 'type_death']].dropna()
selData.head()
# Out:
#   icd10_chapter    age_group type_death
# 0       K00–K93  45-54 years        nan
# 1       K00–K93  55-64 years        nan
# 2       K00–K93  75-84 years        nan
# 3       K00–K93  75-84 years    natural
# 4       K00–K93  75-84 years    natural

# %% [markdown]
# # Visualization

# %%
#sns.set_theme('bmh')
#plt.style.use('plot-style-name-goes-here')
sns.set()
sns.set_context('poster',rc={"grid.linewidth": 5})
sns.set_style("whitegrid")
#sns.set_context("notebook")
colors = ["#5998B1","#406F82","#264653","#287271","#2a9d8f","#8AB17D","#E9C46A","#EFB366","#F4A261","#E76F51","#C53D1B","#923B26"]
#colors = ["#345E6F","#264653","#287271","#2a9d8f","#e9c46a","#efb366","#f4a261","#ee8959","#e76f51","#e87153","#e97c61", '#902C14']
f_folors = ["#E76F51","#F4A261","#E9C46A","#2A9D8F","#264653"]

bin_colors = ["#264653","#2A9D8F"]
sns.set_palette(sns.color_palette(colors))
mul_palette = sns.color_palette(colors)
bin_palette = sns.color_palette(bin_colors)
f_palette = sns.color_palette(f_folors)
sns.set(rc={'figure.figsize':(10,5)}, font_scale=1.5)
sns.set_style({'axes.facecolor':'white', 'grid.color': '.8','grid.linestyle': '--'})

# %% [markdown]
# ### Type of Death per month with respect to race

# %%
sns.scatterplot( ds_sql['month'], ds_sql['race'], hue =ds_sql["type_death"])
plt.legend( bbox_to_anchor=(1.05, 1))
ax.axes.xaxis.set_visible(False)

# %% [markdown]
# ## Number of people died in a month

# %%
mdeath = ds_sql['month'].value_counts()
sns.set(style="darkgrid")
sns.barplot(mdeath.index, mdeath.values, alpha=0.9)
plt.title('Number of people died in a month')
plt.ylabel('Number of Death', fontsize=10)
plt.xlabel('month', fontsize=12)
plt.show()

# %%
# Plot  top 10 causes of death
ax = sns.countplot(y='icd10_chapter', data=ds_sql , order = ds_sql['icd10_chapter'].value_counts().iloc[:10].index,palette=mul_palette)
# ADDED: Remove labels.
ax.axes.xaxis.set_visible(False)
ax.set_ylabel('')
ax.set(title='Top 10 causes of death in 2019 (USA)')
ax.axes.xaxis.set_visible(False)

# %% [markdown]
# ## Death by icd code in US

# %%
#Death by icd code in US
 
axn = sns.countplot(y='icd10_chapter',data=ds_sql, color='black', order = ds_sql.icd10_chapter.value_counts().index)
axn.set(ylabel="ICD10 Code Standard",title="Death By ICD 10 code - US")
ax.axes.xaxis.set_visible(False)

# %% [markdown]
# ## Type of Death per Month

# %%
ax=sns.lineplot( ds_sql['type_death'], ds_sql['month'])
ax.set(ylabel="",title='Death Per Month in US')
ax.set(xlabel="Cause of Death")
ax.set(ylabel="Month")
ax.axes.xaxis.set_visible(True)

# %%
# CountPlot - ICD 10 code Distribution 

cp=sns.countplot(x='icd10_chapter', data=ds_sql, color='green')
sns.set(style="darkgrid")
cp.set(xticklabels=[])
cp.set(title="ICD 10 Distribution")
ax.axes.xaxis.set_visible(False)

# %% [markdown]
# ## Heatmap Death by icd code in US

# %%
column = 'icd10_chapter'
us  = ds_sql[column].value_counts(normalize=True)

# create a dictonary
data = {"Death by ICD10 Code in US": us,}
df_total_age = pd.concat(data,
               axis = 1)
df_total_age = df_total_age.fillna(0)
plt.figure(figsize=(7.5,10))
ax=sns.heatmap(df_total_age,annot=True,fmt ='.2%' )
ax.set(ylabel="",title='Percentage of cause of death in US')
ax.axes.xaxis.set_visible(False)

# %%
# to check which residential area has the highest number of death
ds_sql['resident_status'].value_counts().plot(kind='barh', figsize=(6,6), 
                                     edgecolor=(0,0,0),color='lightblue', title='Death by resident status')
ax.axes.xaxis.set_visible(False)

# %%
# highest death count with respect to gender

axn = sns.countplot(x='sex',data=ds_sql, order = ds_sql.sex.value_counts().index)
axn.set(ylabel="",title="Death count by gender - USA Data")
ax.axes.xaxis.set_visible(False)

# %%
# Pairplot for Death in US 
 
sns.pairplot(ds_sql,height=7.7, aspect=7.7/7.7)
ax.set(ylabel="",title= 'Pairplot for Death in US')
ax.axes.xaxis.set_visible(False)

# %%
plt.figure(figsize=(7.5,10))
mul_palette = sns.color_palette(colors)
ax = sns.countplot( y = 'age_group',data=ds_sql, palette=mul_palette)
ax.set(ylabel="",title='Number of Death with respect to Age-Group')
ax.axes.xaxis.set_visible(False)

# %% [markdown]
# # Drop table in postgresql

# %%
#drop table in postgresql
#cursor = conn.cursor()
#cursor.execute("DROP TABLE us_mort;")
#conn.commit()
#cursor.close()
